# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Query url       
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Empty lists
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the counter
record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop through cities and use try/except to exclude cities not in API
for city in cities:  
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
         
        record= record + 1
        

        time.sleep(1.01)
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Nileshwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=nileshwar
# Processing Record 2 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=yellowknife
# Processing Record 3 | Terenos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=terenos
# Processing Record 4 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=tuktoyaktuk
# Processing Record 5 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=rikitea
# Processing Record 6 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66b6b853198de3d677b08d332bc8be9f&q=provideniya
# Processing Record 7 | Anchorage
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dictionary
dictionary = {'City': city_name,
             'Cloudiness': cloudiness,
             'Country': country,
             'Date': date,
             'Humidity': humidity,
             'Lat': lat,
             'Lng': lng,
             'Max Temp': max_temp,
             'Wind Speed': wind_speed}

weather_data = pd.DataFrame(dictionary)

weather_data.count()
# Out:
# City          526
# Cloudiness    526
# Country       526
# Date          526
# Humidity      526
# Lat           526
# Lng           526
# Max Temp      526
# Wind Speed    526
# dtype: int64

# %%
#Create csv file with data
weather_data.to_csv('weather_data.csv')

# display df
weather_data.head(10)
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Nileshwar          93      IN  1569794302        93  12.25   75.10
# 1  Yellowknife          20      CA  1569794303        52  62.45 -114.38
# 2      Terenos           0      BR  1569794305        29 -20.44  -54.87
# 3  Tuktoyaktuk          40      CA  1569794306        75  69.44 -133.03
# 4      Rikitea          91      PF  1569794307        73 -23.12 -134.97
# 5  Provideniya           0      RU  1569794309        81  64.42 -173.23
# 6    Anchorage          90      US  1569794310        81  61.22 -149.89
# 7     Yarmouth          75      CA  1569794256        62  43.84  -66.12
# 8      Zarautz          90      ES  1569794312        72  43.28   -2.17
# 9      Te Anau          82      NZ  1569794314        79 -45.41  167.72
#
#    Max Temp  Wind Speed
# 0     75.67        7.23
# 1     46.40       16.11
# 2     89.60        8.05
# 3     41.00        9.17
# 4     70.71        7.78
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plot graph of tmeperature vs latitude
plt.scatter(weather_data['Lat'], weather_data['Max Temp'], marker='o', s=50, facecolors='skyblue', edgecolors='black')
plt.title('City Latitude vs Max Temperature (9/29/19)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()

# save plot
plt.savefig('City_LatitudeVsMax_Temp.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#plot graph of latitude vs humidity
plt.scatter(weather_data['Lat'], weather_data['Humidity'], marker='o', s=50, facecolors='skyblue', edgecolors='black')
plt.title('City Latitude vs Humidity (9/29/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save plot
plt.savefig('City_Latitude_Vs_Humidity.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plot latitude vs cloudiness
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'], marker='o', s=50, facecolors='skyblue', edgecolors='black')
plt.title('City Latitude vs Clousiness (9/29/19)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

#save plot
plt.savefig('City_Latitude_vs_Cloudiness.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# create plot
plt.scatter(weather_data['Lat'], weather_data['Wind Speed'], marker='o', s=50, facecolors='skyblue', edgecolors='black')
plt.title('City Latitude vs Wind Speed (9/29/19)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()

#save plot
plt.savefig('City_Latitude_vs_Wind_Speed.png')
